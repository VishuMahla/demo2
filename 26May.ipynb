# %%
c = 1 + 2j;
print("Read Part = ", c.real)
print("Imaginary Part = ", c.imag)
# Out:
# Read Part =  1.0
# Imaginary Part =  2.0

# %%
c1 = 2.5 + 2.5j
c2 = 3.0 - 0.5j
c3 = c1.imag + c2.imag
print("Sum  = " + (int)c3)
# Out:
#   Cell In[6], line 4
#     print("Sum  = " + (int)c3)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
str1 = """This is a simple example on strings where we are giving multiple lines in a single string variables """
print(str1)
# Out:
# This is a simple example on strings where er are giving multiple lines in a single string variables

# %%
name1 = "vishal"
name2 = name1;
print(name1 == name2)
print(name2)
name2 = "prasuram"
print(name1)
# Out:
# True
# vishal
# vishal

# %%
str3 = '''This is a "String Demo" in python '''
print(str3)
# Out:
# This is a "String Demo" in python

# %%
naam = "Mukesh MC"
print(naam[-2:])
# Out:
# MC

# %%
print(naam[3:])
print(naam[1:7])
print(naam*2)
# Out:
# esh MC
# ukesh
# Mukesh MCMukesh MC

# %%
elements = [10,20,4,30,14] #creating a list 
x = bytes(elements) # converitng the list into byte styles
print(x[0])
for i in x: print(i)
type(x)
# Out:
# 10
# 10
# 20
# 4
# 30
# 14
# bytes

# %%
for i in elements: print(i);

for i in elements: print(i , end = " this is the end ")
elements[3] = 254;
for i in elements: print(i);
# Out:
# 10
# 20
# 4
# 30
# 14
# 10 this is the end 20 this is the end 4 this is the end 30 this is the end 14 this is the end 10
# 20
# 4
# 254
# 14

# %%
list = [10,43,23,86,98,9]
list[5] = 55;
for i in list: print(i)
# Out:
# 10
# 43
# 23
# 86
# 98
# 55

# %%
byteeee = bytes(list);
# byteeee[4] = 101;   not possible in python because bytes is immutable
for i in byteeee: print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 byteeee = bytes(list);
# ----> 2 byteeee[4] = 101;
#       3 for i in byteeee: print(i)
#
# TypeError: 'bytes' object does not support item assignment

# %%
arr = [10,20,30,40,50,60]
arr[2] = 22;
for i in arr: print(i)
# Out:
# 10
# 20
# 22
# 40
# 50
# 60

# %%
list1 = [103,42,678,23,90]
list2 = [12,8,12,9,23]
print(list1 + list2)
# Out:
# [103, 42, 678, 23, 90, 12, 8, 12, 9, 23]

# %%
l1 = [1,2,3,4,5,6,7,8]
print(4 in l1)
print(34 not in list1)
# Out:
# True
# True

# %%
tupl = (1,2,3,5,7,8,'ramu', 'kaku','jhadu')
print(tupl)
print(tupl*2)
print(tupl)
# Out:
# (1, 2, 3, 5, 7, 8, 'ramu', 'kaku', 'jhadu')
# (1, 2, 3, 5, 7, 8, 'ramu', 'kaku', 'jhadu', 1, 2, 3, 5, 7, 8, 'ramu', 'kaku', 'jhadu')
# (1, 2, 3, 5, 7, 8, 'ramu', 'kaku', 'jhadu')
