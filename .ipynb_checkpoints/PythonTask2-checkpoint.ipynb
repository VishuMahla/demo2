# %%
# What is 7 to the power of 4?
# write your code here
print(7**4)
# Out:
# 2401

# %%
# Split this string into a list.
s = "Hi there Sam!"
print(s.split(' '))
# Out:
# ['Hi', 'there', 'Sam!']

# %%
# Given the variables:
planet = "Earth"
diameter = 12742
# write your code here
# Use .format() to print the following string:
# Expected Output : The diameter of Earth is 12742 kilometers.
print("The diameter of {} is {} kilometers".format(planet, diameter))
print(f"The diameter of {planet} is {diameter} kilometers")
# Out:
# The diameter of Earth is 12742 kilometers
# The diameter of Earth is 12742 kilometers

# %%
# Given this nested list, use indexing to grab the word "hello" 
list = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]
# write your code here
#Expected output : 'hello'
print(list[3][1][2][0])
# Out:
# hello

# %%
# Given this nested dictionary grab the word "hello". 
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}
# write your code here
print(d['k1'][3]['tricky'][3]['target'][3])
# Out:
# hello

# %%
# What is the main difference between a tuple and a list? 
# Type your answer here. 
#Tuple is a readonly list and unmutable whereas list is mutable 
# List is hashable and the tuple is non hashable

# %%
# Create a function that grabs the email website domain from a string in the form: 

#So for example, passing "user@domain.com" would return: domain.com"
# write your code here
# domainGet('user@domain.com') #calling function
gmail = "user@domain.com"
def grabMail(mail):
    return mail.split("@")[1]
print(grabMail(gmail));
# Out:
# domain.com

# %%
# Create a basic function that returns True if the word 'dog' is contained in the 
#input string. Don't worry about edge cases like a punctuation being attached to 
#the word dog, but do account for capitalization.
# write your code here 
def findDog(sentence):
    return bool(sentence.lower().find('dog')+1)
    # return 'dog' in sentence
findDog('Is there a Dog here?') # calling function
# Out:
# True

# %%
 #Create a function that counts the number of times the word "dog" occurs in a 
#string. Again ignore edge cases. **
# write your code here 
def countDog(string):
    return string.lower().count('dog')
print(countDog('This dog runs faster than the other dog dude!') )# calling function
# Out:
# 2

# %%
# Use lambda expressions and the filter() function to filter out words from a list 
# that don't start with the letter 's'. For example:
seq = ['soup','dog','salad','cat','great']

print(list(filter(lambda s: not s.startswith('s'),seq)))
# Out:
# ['dog', 'cat', 'great']

# %%
#Final Problem
# You are driving a little too fast, and a police officer stops you. Write a function to 
#return one of 3 possible results: "No ticket", "Small ticket", or "Big Ticket". If your 
#speed is 60 or less, the result is "No Ticket". If speed is between 61 and 80 
#inclusive, the result is "Small Ticket". If speed is 81 or more, the result is "Big 
#Ticket". Unless it is your birthday (encoded as a boolean value in the parameters of 
#the function) -- on your birthday, your speed can be 5 higher in all cases. 
def caught_speeding(speed, is_birthday):
    if(is_birthday): speed -= 5
    if(speed <= 60): return "No Ticket"
    if(speed >= 61 and speed <= 80): return "Small Ticket"
    return "Big Ticket"

 # write your code here
print(caught_speeding(81,True))
#'Small Ticket'
print(caught_speeding(81,False))
print(caught_speeding(98,True))

#'Big Ticket'
# Out:
# Small Ticket
# Big Ticket
# Big Ticket
