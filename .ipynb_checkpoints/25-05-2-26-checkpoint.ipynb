# %%
print("Hello World")
# Out:
# Hello World

# %%
print("hello world")
# Out:
# hello world

# %%
a, b = 10,20;
print(a + b)
# Out:
# 30

# %%
print(10/6)
# Out:
# 1.6666666666666667

# %%
def hello() :
    print("hello")
x = hello();
print(x);
# Out:
# hello
# None

# %%
# swap two numbers
a, b = 10, 20;
a,b = b, a
print(a);
print(b);
print(f"the value of a is: {a} and the value of b is : {b}")
# Out:
# 20
# 10
# the value of a is: 20 and the value of b is : 10

# %%
# print(a)
z = None;

# print(z);

# print(type(z));
# print(type(56));
# print(type("bang"));
h = 4 + 3j;
print(type(h));
# Out:
# <class 'complex'>

# %%
def oddIncrement(n):
    i = 1;
    sum = 0;
    while(i < n):
        sum = sum + i;
        i = i + 2;
    return sum;
print(oddIncrement(100));
# Out:
# 2500

# %%
#sum of 2 float values
a = 2.5;
b = 3.1;
c = a + b;
print(c)
type(c)
# Out:
# 5.6
# float
