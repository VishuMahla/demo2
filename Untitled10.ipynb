# %%
#Lambda Methods

isMinor = lambda x: 'Major' if x > 18 else 'Minor'
print(isMinor(20))
# Out:
# Major

# %%
type(lambda x: 'Major' if x > 18 else 'Minor')
# Out:
# function

# %%
#Seaborn is a powerful python data visualization library built on top of matplotlin 
# it provides a high level interface for creating attractive and informative statistical graphics 
import seaborn as sns 
import matplotlib.pyplot as plt
df = sns.load_dataset("tips")
print(df)
print(df["total_bill"])
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %% [markdown]
# histogram
# KDE(Kernal Density Estimate)
# Historam with KDE
# Distribution plot
# numpy topics
# array basics indexing and slicing
# broad casting and vectorization
# aggregation and math functions
# cum sum cum product
# and access via reductions
#     reshaping and stacking
#     reshape, Platten, rathen , transopse concatinate, b stack , h stack , heap, split
#
#
#     #pandas
#     series and dataframe basics
#     indexing and slicing , selection
#     filtering and sorting
#     group by and aggregation
#     merging and joining
#     reshaping
#     missing data isnull nan
#     apply and vectorization and operation apply map , string data time access .bt, .something , lambda functions
#
#     #statics and exploratory data analysis
#     # data visualization
#     # map (mat) plot basics comman plot
#     # seaborn
# # chossing the right chart
# categoruical numerical datatype

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
df = sns.load_dataset("tips")
print(df)
print(df["total_bill"])
tips = sns.lead_dataset("tips")
sns.histplot(tips['total_bill'])
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64
# ...

# %%
sns.kdeplot(tips['total_bill'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sns.kdeplot(tips['total_bill'])
#
# NameError: name 'tips' is not defined

# %%
sns.histplot(tips['total_bill'], kde= True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sns.histplot(tips['total_bill'], kde= True)
#       2 plt.show()
#
# NameError: name 'tips' is not defined

# %%
sns.displot(x = 'day', y = 'total_bill', data = tips) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sns.displot(x = 'day', y = 'total_bill', data = tips)
#       2 plt.show()
#
# NameError: name 'tips' is not defined

# %%
#Matrix Plots
corr = tips.corr(numeric_only = True)
sns.heatmap(corr, annot = True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 #Matrix Plots
# ----> 2 corr = tips.corr(numeric_only = True)
#       3 sns.heatmap(corr, annot = True)
#       4 plt.show()
#
# NameError: name 'tips' is not defined

# %%
#clustor map 
import seaborn as sns 
import matplotlib.pyplot as plt
sns.clustermap(corr, annot = True) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
# ----> 4 sns.clustermap(corr, annot = True)
#       5 plt.show()
#
# NameError: name 'corr' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("tips")

sns.pairplot(df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("tips")
sns.FacetGrid(tips, col = "sex")
g.map(sns.histplot, "total_bill")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       2 import matplotlib.pyplot as plt
#       4 df = sns.load_dataset("tips")
# ----> 5 sns.FacetGrid(tips, col = "sex")
#       6 g.map(sns.histplot, "total_bill")
#       7 plt.show()
#
# NameError: name 'tips' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset("tips")
sns.set_style("whitegrid")
sns.histplot(df['total_bill'])
plt.show()

# %%
#color palettes

sns.set_palette("Set1")
sns.countplot(x = 'day', data = df)
plt.show()
